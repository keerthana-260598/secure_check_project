# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# %%
pd.read_csv(r"C:\Users\ACER\Desktop\traffic_stops - traffic_stops_with_vehicle_number.csv",low_memory=False)
df = pd.read_csv(r"C:\Users\ACER\Desktop\traffic_stops - traffic_stops_with_vehicle_number.csv",low_memory=False)

# %%
df
# Out:
#         stop_date stop_time country_name driver_gender  driver_age_raw  \
# 0      2020-01-01   0:00:00       Canada             M              59
# 1      2020-01-01   0:01:00        India             M              35
# 2      2020-01-01   0:02:00          USA             M              26
# 3      2020-01-01   0:03:00       Canada             M              26
# 4      2020-01-01   0:04:00       Canada             M              62
# ...           ...       ...          ...           ...             ...
# 65533  2020-02-15  12:13:00        India             F              54
# 65534  2020-02-15  12:14:00       Canada             F              18
# 65535  2020-02-15  12:15:00          USA             M              27
# 65536  2020-02-15  12:16:00       Canada             F              49
# 65537  2020-02-15  12:17:00          USA             F              72
#
#        driver_age driver_race     violation_raw violation  search_conducted  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65538 entries, 0 to 65537
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   stop_date           65538 non-null  object
#  1   stop_time           65538 non-null  object
#  2   country_name        65538 non-null  object
#  3   driver_gender       65538 non-null  object
#  4   driver_age_raw      65538 non-null  int64
#  5   driver_age          65538 non-null  int64
#  6   driver_race         65538 non-null  object
#  7   violation_raw       65538 non-null  object
#  8   violation           65538 non-null  object
#  9   search_conducted    65538 non-null  bool
#  10  search_type         43818 non-null  object
#  11  stop_outcome        65538 non-null  object
#  12  is_arrested         65538 non-null  bool
#  13  stop_duration       65538 non-null  object
#  14  drugs_related_stop  65538 non-null  bool
# ...

# %%
df['stop_date'] = pd.to_datetime(df['stop_date'],format= '%Y-%m-%d')

# %%
df['stop_time'] = pd.to_datetime(df['stop_time'],format= '%H:%M:%S')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65538 entries, 0 to 65537
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   stop_date           65538 non-null  datetime64[ns]
#  1   stop_time           65538 non-null  datetime64[ns]
#  2   country_name        65538 non-null  object
#  3   driver_gender       65538 non-null  object
#  4   driver_age_raw      65538 non-null  int64
#  5   driver_age          65538 non-null  int64
#  6   driver_race         65538 non-null  object
#  7   violation_raw       65538 non-null  object
#  8   violation           65538 non-null  object
#  9   search_conducted    65538 non-null  bool
#  10  search_type         43818 non-null  object
#  11  stop_outcome        65538 non-null  object
#  12  is_arrested         65538 non-null  bool
#  13  stop_duration       65538 non-null  object
#  14  drugs_related_stop  65538 non-null  bool
# ...

# %%
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 65533    False
# 65534    False
# 65535    False
# 65536    False
# 65537    False
# Length: 65538, dtype: bool

# %%
print(df.isnull().sum())
# Out:
# stop_date                 0
# stop_time                 0
# country_name              0
# driver_gender             0
# driver_age_raw            0
# driver_age                0
# driver_race               0
# violation_raw             0
# violation                 0
# search_conducted          0
# search_type           21720
# stop_outcome              0
# is_arrested               0
# stop_duration             0
# drugs_related_stop        0
# vehicle_number            0
# dtype: int64

# %%
print(df.isnull().sum().sum())
# Out:
# 21720

# %%
df[df.isnull().any(axis=1)]
# Out:
#        stop_date           stop_time country_name driver_gender  \
# 7     2020-01-01 1900-01-01 00:07:00        India             M
# 9     2020-01-01 1900-01-01 00:09:00          USA             M
# 10    2020-01-01 1900-01-01 00:10:00        India             F
# 13    2020-01-01 1900-01-01 00:13:00          USA             M
# 14    2020-01-01 1900-01-01 00:14:00        India             M
# ...          ...                 ...          ...           ...
# 65523 2020-02-15 1900-01-01 12:03:00        India             F
# 65529 2020-02-15 1900-01-01 12:09:00        India             F
# 65530 2020-02-15 1900-01-01 12:10:00        India             M
# 65536 2020-02-15 1900-01-01 12:16:00       Canada             F
# 65537 2020-02-15 1900-01-01 12:17:00          USA             F
#
#        driver_age_raw  driver_age driver_race     violation_raw violation  \
# 7                  72          50       Asian     Drunk Driving     Other
# ...

# %%
df.fillna("Unknown", inplace=True)

# %%
print(df.isnull().sum().sum())
# Out:
# 0

# %%
print(df.isnull().sum())
# Out:
# stop_date             0
# stop_time             0
# country_name          0
# driver_gender         0
# driver_age_raw        0
# driver_age            0
# driver_race           0
# violation_raw         0
# violation             0
# search_conducted      0
# search_type           0
# stop_outcome          0
# is_arrested           0
# stop_duration         0
# drugs_related_stop    0
# vehicle_number        0
# dtype: int64

# %%
df
# Out:
#         stop_date stop_time country_name driver_gender  driver_age_raw  \
# 0      2020-01-01   0:00:00       Canada             M              59
# 1      2020-01-01   0:01:00        India             M              35
# 2      2020-01-01   0:02:00          USA             M              26
# 3      2020-01-01   0:03:00       Canada             M              26
# 4      2020-01-01   0:04:00       Canada             M              62
# ...           ...       ...          ...           ...             ...
# 65533  2020-02-15  12:13:00        India             F              54
# 65534  2020-02-15  12:14:00       Canada             F              18
# 65535  2020-02-15  12:15:00          USA             M              27
# 65536  2020-02-15  12:16:00       Canada             F              49
# 65537  2020-02-15  12:17:00          USA             F              72
#
#        driver_age driver_race     violation_raw violation  search_conducted  \
# ...

# %%
pip install mysql-connector-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import mysql.connector

# %%
mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  password="shailesh",
  auth_plugin='mysql_native_password'
)

# %%
cursor_mysql = mydb.cursor()
print("MySQL connection established!")
# Out:
# MySQL connection established!

# %%
cursor_mysql.execute("CREATE DATABASE IF NOT EXISTS secure_check;")
print("MySQL database 'secure_check' created successfully!")
# Out:
# MySQL database 'secure_check' created successfully!

# %%
cursor_mysql.execute("USE secure_check;")

# %%
cursor_mysql.execute("""
    CREATE TABLE IF NOT EXISTS secure_check (
        stop_date DATE,
        stop_time TIME,
        country_name VARCHAR(50),
        driver_gender CHAR(1),
        driver_age_raw INT,
        driver_age INT,
        driver_race VARCHAR(50),
        violation_raw VARCHAR(50),
        violation VARCHAR(50),
        search_conducted BOOL,
        search_type VARCHAR(50) ,
        stop_outcome VARCHAR(50) ,
        is_arrested BOOL,
        stop_duration VARCHAR(50)  ,
        drugs_related_stop BOOL,
        vehicle_number VARCHAR(50)                                                                              
    );
""")
mydb.commit()
print("Table 'secure_check' created successfully in MySQL!")
# Out:
# Table 'secure_check' created successfully in MySQL!

# %%
data_list = df.values.tolist()
query = """
    INSERT INTO secure_check (
           stop_date, stop_time, country_name, driver_gender, driver_age_raw, driver_age, driver_race, violation_raw, violation,
           search_conducted, search_type, stop_outcome, is_arrested, stop_duration, drugs_related_stop, vehicle_number)
    VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s);
"""
cursor_mysql.executemany(query, data_list)
mydb.commit()
print("Data inserted using to_list()")
# Out:
# Data inserted using to_list()

# %%
pip install seaborn
# Out:
# ...
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.1 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.1 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/8.1 MB 558.9 kB/s eta 0:00:14
#    -- ------------------------------------- 0.5/8.1 MB 558.9 kB/s eta 0:00:14
#    --- ------------------------------------ 0.8/8.1 MB 549.6 kB/s eta 0:00:14
#    --- ------------------------------------ 0.8/8.1 MB 549.6 kB/s eta 0:00:14
#    --- ------------------------------------ 0.8/8.1 MB 549.6 kB/s eta 0:00:14
#    ----- ---------------------------------- 1.0/8.1 MB 479.2 kB/s eta 0:00:15
#    ----- ---------------------------------- 1.0/8.1 MB 479.2 kB/s eta 0:00:15
#    ----- ---------------------------------- 1.0/8.1 MB 479.2 kB/s eta 0:00:15
# ...

# %%
import matplotlib as plt

# %%
from matplotlib import pyplot as plt

# %%
pip install plotly
# Out:
# ...
#    ---------------------------------------- 0.0/9.8 MB ? eta -:--:--
#    ------ --------------------------------- 1.6/9.8 MB 12.0 MB/s eta 0:00:01
#    ----------------- ---------------------- 4.2/9.8 MB 11.4 MB/s eta 0:00:01
#    --------------------------- ------------ 6.8/9.8 MB 11.7 MB/s eta 0:00:01
#    ------------------------------------- -- 9.2/9.8 MB 11.6 MB/s eta 0:00:01
#    ---------------------------------------- 9.8/9.8 MB 11.3 MB/s  0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
